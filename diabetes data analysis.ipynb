# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("./diabetes_unclean.csv")
df
pd.set_option("display.max_row", 20)
df
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %%
df.nunique()
# Out:
# ID           800
# No_Pation    961
# Gender         3
# AGE           49
# Urea         110
# Cr           113
# HbA1c        111
# Chol          77
# TG            69
# HDL           48
# LDL           65
# VLDL          60
# BMI           64
# CLASS          5
# dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    570
# F    437
# f      2
# Name: count, dtype: int64

# %%
df["Gender"] = df["Gender"].replace({"f" : "F"})
#df["Gender"] = df["Gender"].map({"f" : "F"})

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    570
# F    439
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().value_counts()
# Out:
# False    1009
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# ID           800
# No_Pation    961
# Gender         2
# AGE           49
# Urea         110
# Cr           113
# HbA1c        111
# Chol          77
# TG            69
# HDL           48
# LDL           65
# VLDL          60
# BMI           64
# CLASS          5
# dtype: int64

# %%
df["AGE"].value_counts()
# Out:
# AGE
# 55.0    184
# 60.0     89
# 54.0     84
# 51.0     51
# 61.0     49
#        ...
# 65.0      2
# 25.0      1
# 79.0      1
# 32.0      1
# 71.0      1
# Name: count, Length: 49, dtype: int64

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df[df["AGE"].isna()]
# Out:
#       ID  No_Pation Gender  AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 979  177      45364      F  NaN   4.6  70.0    9.6   4.1  1.8  1.0  2.3   0.8
#
#       BMI CLASS
# 979  30.0     Y

# %%
df["AGE"] = df["AGE"].fillna(df["AGE"].mean())

# %%
df["AGE"] = df["AGE"].astype(int)

# %%
df["AGE"].value_counts()
# Out:
# AGE
# 55    184
# 60     89
# 54     84
# 51     51
# 61     49
#      ...
# 65      2
# 25      1
# 79      1
# 32      1
# 71      1
# Name: count, Length: 49, dtype: int64

# %%
df.nunique()
# Out:
# ID           800
# No_Pation    961
# Gender         2
# AGE           49
# Urea         110
# Cr           113
# HbA1c        111
# Chol          77
# TG            69
# HDL           48
# LDL           65
# VLDL          60
# BMI           64
# CLASS          5
# dtype: int64

# %%
df["ID"].value_counts()
# Out:
# ID
# 188    3
# 191    3
# 195    3
# 193    3
# 189    3
#       ..
# 353    1
# 356    1
# 488    1
# 508    1
# 248    1
# Name: count, Length: 800, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
df.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
df["ID"].duplicated().sum()
# Out:
# 209

# %%
df.rename(columns={'ID' : 'Patient ID', 'No_Pation' : "Patient NO", 'Gender' : 'Gender', 'AGE' : 'Age', 'Urea' : 'Urea', 'Cr' : 'Creatinine', 'HbA1c' : 'Homoglobin Percentage', 'Chol' : 'Cholesterol', 'TG' : 'Triglycerides Lipids', 'HDL' : 'High-Density Lipoprotein', 'LDL' : 'Low-Density Lipoprotein', 'VLDL' : 'Very-Low-Density Lipoprotein', 'BMI' : 'Body Mass Index', 'CLASS' : 'Class'}, inplace=True)

# %%
df.head()
# Out:
#    Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 0         502       17975      F   50   4.7        46.0
# 1         735       34221      M   26   4.5        62.0
# 2         420       47975      F   50   4.7        46.0
# 3         680       87656      F   50   4.7        46.0
# 4         504       34223      M   33   7.1        46.0
#
#    Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 0                    4.9          4.2                   0.9
# 1                    4.9          3.7                   1.4
# 2                    4.9          4.2                   0.9
# 3                    4.9          4.2                   0.9
# 4                    4.9          4.9                   1.0
#
#    High-Density Lipoprotein  Low-Density Lipoprotein  \
# 0                       2.4                      1.4
# 1                       1.1                      2.1
# 2                       2.4                      1.4
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# Y     840
# N     102
# P      53
# Y      13
# N       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 0         502       17975      F   50   4.7        46.0
# 1         735       34221      M   26   4.5        62.0
# 2         420       47975      F   50   4.7        46.0
# 3         680       87656      F   50   4.7        46.0
# 4         504       34223      M   33   7.1        46.0
#
#    Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 0                    4.9          4.2                   0.9
# 1                    4.9          3.7                   1.4
# 2                    4.9          4.2                   0.9
# 3                    4.9          4.2                   0.9
# 4                    4.9          4.9                   1.0
#
#    High-Density Lipoprotein  Low-Density Lipoprotein  \
# 0                       2.4                      1.4
# 1                       1.1                      2.1
# 2                       2.4                      1.4
# ...

# %%
df["Patient ID"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1004     True
# 1005     True
# 1006     True
# 1007     True
# 1008     True
# Name: Patient ID, Length: 1009, dtype: bool

# %%
df["Patient ID"].drop_duplicates(inplace=True)

# %%
df["Patient ID"].duplicated().sum()
# Out:
# 209

# %%
df["Patient ID"] = df["Patient ID"].drop_duplicates()

# %%
df["Patient ID"].duplicated().sum()
# Out:
# 208

# %%
df[df["Patient ID"].isna()]
# Out:
#       Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 77           NaN       45396      M   51   4.5        88.0
# 80           NaN       45399      F   57   4.6        97.0
# 156          NaN       23975      M   31   3.0        60.0
# 174          NaN       34278      F   46   3.0        59.0
# 176          NaN       24005      F   54   3.0        39.0
# ...          ...         ...    ...  ...   ...         ...
# 1004         NaN      454316      M   55   NaN        62.0
# 1005         NaN      454316      M   55   4.8        88.0
# 1006         NaN      454316      M   62   6.3        82.0
# 1007         NaN      454316      F   57   4.1        70.0
# 1008         NaN        4543      F   55   4.1        34.0
#
#       Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 77                      4.0          4.1                   1.5
# 80                      0.9          3.2                   1.3
# 156                    12.3          4.1                   2.2
# ...

# %%
df["Patient ID"] = df["Patient ID"].fillna(0)

# %%
df.nunique()
# Out:
# Patient ID                      801
# Patient NO                      961
# Gender                            2
# Age                              49
# Urea                            110
# Creatinine                      113
# Homoglobin Percentage           111
# Cholesterol                      77
# Triglycerides Lipids             69
# High-Density Lipoprotein         48
# Low-Density Lipoprotein          65
# Very-Low-Density Lipoprotein     60
# Body Mass Index                  64
# Class                             5
# dtype: int64

# %%
df.isna().sum()
# Out:
# Patient ID                      0
# Patient NO                      0
# Gender                          0
# Age                             0
# Urea                            1
# Creatinine                      2
# Homoglobin Percentage           3
# Cholesterol                     2
# Triglycerides Lipids            2
# High-Density Lipoprotein        1
# Low-Density Lipoprotein         2
# Very-Low-Density Lipoprotein    1
# Body Mass Index                 0
# Class                           0
# dtype: int64

# %%
df.head()
# Out:
#    Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 0       502.0       17975      F   50   4.7        46.0
# 1       735.0       34221      M   26   4.5        62.0
# 2       420.0       47975      F   50   4.7        46.0
# 3       680.0       87656      F   50   4.7        46.0
# 4       504.0       34223      M   33   7.1        46.0
#
#    Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 0                    4.9          4.2                   0.9
# 1                    4.9          3.7                   1.4
# 2                    4.9          4.2                   0.9
# 3                    4.9          4.2                   0.9
# 4                    4.9          4.9                   1.0
#
#    High-Density Lipoprotein  Low-Density Lipoprotein  \
# 0                       2.4                      1.4
# 1                       1.1                      2.1
# 2                       2.4                      1.4
# ...

# %%
df[df["Urea"].isna()]
# Out:
#       Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 1004         0.0      454316      M   55   NaN        62.0
#
#       Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 1004                    6.8          5.3                   2.0
#
#       High-Density Lipoprotein  Low-Density Lipoprotein  \
# 1004                       1.0                      3.5
#
#       Very-Low-Density Lipoprotein  Body Mass Index Class
# 1004                           0.9             30.1    Y

# %%
df["Urea"] = df["Urea"].fillna(df["Urea"].mean())

# %%
df.isna().sum()
# Out:
# Patient ID                      0
# Patient NO                      0
# Gender                          0
# Age                             0
# Urea                            0
# Creatinine                      2
# Homoglobin Percentage           3
# Cholesterol                     2
# Triglycerides Lipids            2
# High-Density Lipoprotein        1
# Low-Density Lipoprotein         2
# Very-Low-Density Lipoprotein    1
# Body Mass Index                 0
# Class                           0
# dtype: int64

# %%
df[df["Creatinine"].isna()]
# Out:
#       Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 963          0.0       45451      F   65   5.0         NaN
# 1001         0.0      454316      F   60   5.0         NaN
#
#       Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 963                     7.0          3.4                   1.6
# 1001                    8.1          5.2                   3.3
#
#       High-Density Lipoprotein  Low-Density Lipoprotein  \
# 963                        0.7                      2.0
# 1001                       1.4                      0.6
#
#       Very-Low-Density Lipoprotein  Body Mass Index Class
# 963                            0.7             26.0     Y
# 1001                           3.0             27.0    Y

# %%
df["Homoglobin Percentage"]= df["Homoglobin Percentage"].fillna(df["Homoglobin Percentage"].mean())

# %%
df["Creatinine"]= df["Creatinine"].fillna(df["Creatinine"].mean())

# %%
df["Cholesterol"]= df["Cholesterol"].fillna(df["Cholesterol"].mean())

# %%
df["Triglycerides Lipids"]= df["Triglycerides Lipids"].fillna(df["Triglycerides Lipids"].mean())

# %%
df["Very-Low-Density Lipoprotein"]= df["Very-Low-Density Lipoprotein"].fillna(df["Very-Low-Density Lipoprotein"].mean())

# %%
df["Low-Density Lipoprotein"]= df["Low-Density Lipoprotein"].fillna(df["Low-Density Lipoprotein"].mean())

# %%
df["High-Density Lipoprotein"]= df["High-Density Lipoprotein"].fillna(df["High-Density Lipoprotein"].mean())

# %%
df.isna().sum()
# Out:
# Patient ID                      0
# Patient NO                      0
# Gender                          0
# Age                             0
# Urea                            0
# Creatinine                      0
# Homoglobin Percentage           0
# Cholesterol                     0
# Triglycerides Lipids            0
# High-Density Lipoprotein        0
# Low-Density Lipoprotein         0
# Very-Low-Density Lipoprotein    0
# Body Mass Index                 0
# Class                           0
# dtype: int64

# %%
df.nunique()
# Out:
# Patient ID                      801
# Patient NO                      961
# Gender                            2
# Age                              49
# Urea                            111
# Creatinine                      114
# Homoglobin Percentage           112
# Cholesterol                      78
# Triglycerides Lipids             70
# High-Density Lipoprotein         49
# Low-Density Lipoprotein          66
# Very-Low-Density Lipoprotein     61
# Body Mass Index                  64
# Class                             5
# dtype: int64

# %%
df.describe()
# Out:
#         Patient ID    Patient NO          Age         Urea   Creatinine  \
# count  1009.000000  1.009000e+03  1009.000000  1009.000000  1009.000000
# mean    317.542121  2.717448e+05    53.619425     5.131094    68.973188
# std     262.100612  3.365681e+06     8.736660     2.929682    59.753929
# min       0.000000  1.230000e+02    25.000000     0.500000     6.000000
# 25%      44.000000  2.406500e+04    51.000000     3.700000    48.000000
# 50%     296.000000  3.439900e+04    55.000000     4.600000    60.000000
# 75%     548.000000  4.539000e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#        Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# count            1009.000000  1009.000000           1009.000000
# mean                8.284155     4.863873              2.348769
# std                 2.529803     1.296039              1.396100
# ...

# %%
df.isna().sum()
# Out:
# Patient ID                      0
# Patient NO                      0
# Gender                          0
# Age                             0
# Urea                            0
# Creatinine                      0
# Homoglobin Percentage           0
# Cholesterol                     0
# Triglycerides Lipids            0
# High-Density Lipoprotein        0
# Low-Density Lipoprotein         0
# Very-Low-Density Lipoprotein    0
# Body Mass Index                 0
# Class                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Patient ID                    1009 non-null   float64
#  1   Patient NO                    1009 non-null   int64
#  2   Gender                        1009 non-null   object
#  3   Age                           1009 non-null   int32
#  4   Urea                          1009 non-null   float64
#  5   Creatinine                    1009 non-null   float64
#  6   Homoglobin Percentage         1009 non-null   float64
#  7   Cholesterol                   1009 non-null   float64
#  8   Triglycerides Lipids          1009 non-null   float64
#  9   High-Density Lipoprotein      1009 non-null   float64
#  10  Low-Density Lipoprotein       1009 non-null   float64
#  11  Very-Low-Density Lipoprotein  1009 non-null   float64
# ...

# %%
df["Class"]
# Out:
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
#         ..
# 1004    Y
# 1005    Y
# 1006    Y
# 1007    Y
# 1008    Y
# Name: Class, Length: 1009, dtype: object

# %%
df["Class"] = df["Class"].replace({"Y " : "Y", "N " : "N"})

# %%
df["Class"].value_counts()
# Out:
# Class
# Y    853
# N    103
# P     53
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Patient ID                      801
# Patient NO                      961
# Gender                            2
# Age                              49
# Urea                            111
# Creatinine                      114
# Homoglobin Percentage           112
# Cholesterol                      78
# Triglycerides Lipids             70
# High-Density Lipoprotein         49
# Low-Density Lipoprotein          66
# Very-Low-Density Lipoprotein     61
# Body Mass Index                  64
# Class                             3
# dtype: int64

# %%
sns.boxplot(df)
plt.rcParams["figure.figsize"] = (20,30)

# %%
df
# Out:
#       Patient ID  Patient NO Gender  Age      Urea  Creatinine  \
# 0          502.0       17975      F   50  4.700000        46.0
# 1          735.0       34221      M   26  4.500000        62.0
# 2          420.0       47975      F   50  4.700000        46.0
# 3          680.0       87656      F   50  4.700000        46.0
# 4          504.0       34223      M   33  7.100000        46.0
# ...          ...         ...    ...  ...       ...         ...
# 1004         0.0      454316      M   55  5.131094        62.0
# 1005         0.0      454316      M   55  4.800000        88.0
# 1006         0.0      454316      M   62  6.300000        82.0
# 1007         0.0      454316      F   57  4.100000        70.0
# 1008         0.0        4543      F   55  4.100000        34.0
#
#       Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 0                  4.900000          4.2                   0.9
# 1                  4.900000          3.7                   1.4
# ...

# %%
outleirs = df[df["Patient NO"]> 0.995]
outleirs
# Out:
#       Patient ID  Patient NO Gender  Age      Urea  Creatinine  \
# 0          502.0       17975      F   50  4.700000        46.0
# 1          735.0       34221      M   26  4.500000        62.0
# 2          420.0       47975      F   50  4.700000        46.0
# 3          680.0       87656      F   50  4.700000        46.0
# 4          504.0       34223      M   33  7.100000        46.0
# ...          ...         ...    ...  ...       ...         ...
# 1004         0.0      454316      M   55  5.131094        62.0
# 1005         0.0      454316      M   55  4.800000        88.0
# 1006         0.0      454316      M   62  6.300000        82.0
# 1007         0.0      454316      F   57  4.100000        70.0
# 1008         0.0        4543      F   55  4.100000        34.0
#
#       Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 0                  4.900000          4.2                   0.9
# 1                  4.900000          3.7                   1.4
# ...

# %%
df.describe()
# Out:
#         Patient ID    Patient NO          Age         Urea   Creatinine  \
# count  1009.000000  1.009000e+03  1009.000000  1009.000000  1009.000000
# mean    317.542121  2.717448e+05    53.619425     5.131094    68.973188
# std     262.100612  3.365681e+06     8.736660     2.929682    59.753929
# min       0.000000  1.230000e+02    25.000000     0.500000     6.000000
# 25%      44.000000  2.406500e+04    51.000000     3.700000    48.000000
# 50%     296.000000  3.439900e+04    55.000000     4.600000    60.000000
# 75%     548.000000  4.539000e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#        Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# count            1009.000000  1009.000000           1009.000000
# mean                8.284155     4.863873              2.348769
# std                 2.529803     1.296039              1.396100
# ...

# %%
df.head()
# Out:
#    Patient ID  Patient NO Gender  Age  Urea  Creatinine  \
# 0       502.0       17975      F   50   4.7        46.0
# 1       735.0       34221      M   26   4.5        62.0
# 2       420.0       47975      F   50   4.7        46.0
# 3       680.0       87656      F   50   4.7        46.0
# 4       504.0       34223      M   33   7.1        46.0
#
#    Homoglobin Percentage  Cholesterol  Triglycerides Lipids  \
# 0                    4.9          4.2                   0.9
# 1                    4.9          3.7                   1.4
# 2                    4.9          4.2                   0.9
# 3                    4.9          4.2                   0.9
# 4                    4.9          4.9                   1.0
#
#    High-Density Lipoprotein  Low-Density Lipoprotein  \
# 0                       2.4                      1.4
# 1                       1.1                      2.1
# 2                       2.4                      1.4
# ...

# %%
df.groupby("Gender")["Age"].count().plot(kind= "bar", figsize=(5,5))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.plot(kind="scatter", y= "Gender", x= "Age", figsize=(10,4))
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.scatterplot(y= "Gender", x= "Age",hue="Class",data=df)
plt.show
plt.title("Gender vs Age by Class")
plt.rcParams["figure.figsize"] = (7,7)

# %%
sns.scatterplot(y= "Gender", x= "Age",hue="Body Mass Index",data=df)
plt.show
plt.title("Gender vs Age by Class")
plt.rcParams["figure.figsize"] = (4,5)

# %%
df1 = df[["Gender","Age","Triglycerides Lipids","High-Density Lipoprotein","Low-Density Lipoprotein", "Very-Low-Density Lipoprotein"]]
df1
# Out:
#      Gender  Age  Triglycerides Lipids  High-Density Lipoprotein  \
# 0         F   50                   0.9                       2.4
# 1         M   26                   1.4                       1.1
# 2         F   50                   0.9                       2.4
# 3         F   50                   0.9                       2.4
# 4         M   33                   1.0                       0.8
# ...     ...  ...                   ...                       ...
# 1004      M   55                   2.0                       1.0
# 1005      M   55                   4.0                       0.9
# 1006      M   62                   2.0                       1.0
# 1007      F   57                   3.3                       1.0
# 1008      F   55                   1.6                       1.6
#
#       Low-Density Lipoprotein  Very-Low-Density Lipoprotein
# 0                         1.4                      0.500000
# 1                         2.1                      0.600000
# ...

# %%
df1.groupby(["Gender","Age"])[["Triglycerides Lipids","High-Density Lipoprotein","Low-Density Lipoprotein", "Very-Low-Density Lipoprotein"]].agg({np.mean,np.min,np.max, np.sum,"count"}).sort_values(by=["Age"],ascending=False)[ :20]
# Out:
#            Triglycerides Lipids                        \
#                            mean amin count amax   sum
# Gender Age
# F      79              3.000000  3.0     1  3.0   3.0
#        77              2.100000  2.1     1  2.1   2.1
# M      77              1.666667  1.1     3  2.8   5.0
# F      76              1.700000  1.7     1  1.7   1.7
# M      76              5.200000  1.6     3  7.0  15.6
#        75              2.400000  2.4     1  2.4   2.4
# F      75              1.600000  1.6     2  1.6   3.2
# M      73              1.814286  1.4     7  3.3  12.7
# F      73              1.500000  1.5     1  1.5   1.5
# M      71              1.700000  1.7     1  1.7   1.7
# F      70              2.300000  1.3     2  3.3   4.6
# M      69              1.925000  1.3     4  3.2   7.7
# F      69              4.300000  3.8     2  4.8   8.6
# M      68              2.875000  1.2     4  4.5  11.5
# F      68              2.325000  1.1     4  4.8   9.3
# ...

# %%
df1.groupby(["Gender","Age"])[["Triglycerides Lipids","High-Density Lipoprotein","Low-Density Lipoprotein", "Very-Low-Density Lipoprotein"]].count()
# Out:
#             Triglycerides Lipids  High-Density Lipoprotein  \
# Gender Age
# F      25                      1                         1
#        28                      2                         2
#        30                      7                         7
#        31                      3                         3
#        32                      1                         1
# ...                          ...                       ...
# M      71                      1                         1
#        73                      7                         7
#        75                      1                         1
#        76                      3                         3
#        77                      3                         3
#
#             Low-Density Lipoprotein  Very-Low-Density Lipoprotein
# Gender Age
# F      25                         1                             1
#        28                         2                             2
# ...

# %%
df1.groupby(["Gender","Age"])[["Triglycerides Lipids","Low-Density Lipoprotein"]].count().sort_values(by=["Age"],ascending=False)[ :20].plot(kind= "bar")
# Out:
# <Axes: xlabel='Gender,Age'>

# %%
df.to_csv("Cleaned diabetes dataset.csv",index=False)
